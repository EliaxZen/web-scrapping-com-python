# %%
import requests
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

driver_path = ChromeDriverManager().install()

# Create a service object with the driver path
service = Service(driver_path)

navegador = webdriver.Chrome(service=service)

navegador.get('https://www.thaisimobiliaria.com.br/imoveis/a-venda/brasilia')

sleep(20)

page_content = navegador.page_source

site = BeautifulSoup(page_content, 'html.parser')

imoveis = site.findAll('a', attrs={'class': 'card_split_vertically borderHover'})

lista_de_imoveis = []

for imovel in imoveis:
        # Título do imóvel
        titulo = imovel.find('h2', attrs={'class': 'card_split_vertically__location'})

        # Link do imovel
        link = site.find('a', attrs={'class': 'card_split_vertically borderHover'})

        # Subtítulo do imóvel
        tipo = imovel.find('p', attrs={'class': 'card_split_vertically__type'})

        # Preco aluguel
        preco_area = imovel.find('div', attrs={'class': 'card_split_vertically__value-container'})
        preco = preco_area.find('p', attrs={'class': 'card_split_vertically__value'})

        # Metro quadrado
        metro = imovel.find('li', attrs={'class': 'card_split_vertically__spec'})

        # quartos, suíte, vagas
        quarto_suite_vaga = imovel.find('ul', attrs={'class': 'card_split_vertically__specs'})
        lista = quarto_suite_vaga.text.split()
        
        

        lista_de_imoveis.append([titulo.text.strip(), tipo.text.strip() , link['href'], preco.text, metro.text.replace('m²', '').strip(), lista])

df_imovel = pd.DataFrame(lista_de_imoveis, columns=['Título', 'Tipo', 'Link', 'Preço','Metro Quadrado', 'Quarto, Suite, Banheiro, Vaga'])
df_imovel.to_excel(r'C:\Users\galva\OneDrive\Documentos\GitHub\web-scrapping-com-python\teste_script\imoveis_scrapping_thais_imobiliaria.xlsx', index=False)
print(df_imovel)
navegador.quit()
driver.quit()
# Out:
#                                   Título                Tipo  \
# 0               Noroeste - Brasília - DF         Apartamento
# 1           Águas Claras - Brasília - DF         Apartamento
# 2                Asa Sul - Brasília - DF         Apartamento
# 3              Asa Norte - Brasília - DF              Kitnet
# 4              Asa Norte - Brasília - DF              Kitnet
# 5              Asa Norte - Brasília - DF              Kitnet
# 6   Asa Norte - Brasília - DFLife Center                Sala
# 7               Lago Sul - Brasília - DF                Casa
# 8               Sudoeste - Brasília - DF  Apartamento duplex
# 9             Lago Norte - Brasília - DF                Casa
# 10              Guará II - Brasília - DF                Casa
# 11               Asa Sul - Brasília - DF         Apartamento
#
#                                                  Link         Preço  \
# 0   /imovel/apartamento-de-105-m-com-3-quartos-nor...  R$ 1.800.000
# 1   /imovel/apartamento-de-105-m-com-3-quartos-nor...    R$ 345.000
# 2   /imovel/apartamento-de-105-m-com-3-quartos-nor...  R$ 1.060.000
# 3   /imovel/apartamento-de-105-m-com-3-quartos-nor...    R$ 275.000
# 4   /imovel/apartamento-de-105-m-com-3-quartos-nor...    R$ 230.000
# 5   /imovel/apartamento-de-105-m-com-3-quartos-nor...    R$ 300.000
# 6   /imovel/apartamento-de-105-m-com-3-quartos-nor...    R$ 149.500
# 7   /imovel/apartamento-de-105-m-com-3-quartos-nor...  R$ 4.150.000
# 8   /imovel/apartamento-de-105-m-com-3-quartos-nor...  R$ 1.015.000
# 9   /imovel/apartamento-de-105-m-com-3-quartos-nor...  R$ 1.495.000
# 10  /imovel/apartamento-de-105-m-com-3-quartos-nor...    R$ 555.000
# 11  /imovel/apartamento-de-105-m-com-3-quartos-nor...    R$ 610.000
#
#    Metro Quadrado                     Quarto, Suite, Banheiro, Vaga
# 0             105    [105, m²3, Quartos1, Suíte3, Banheiros1, Vaga]
# 1              35               [35, m²1, Quarto1, Banheiro1, Vaga]
# 2              98     [98, m²3, Quartos1, Suíte2, Banheiros1, Vaga]
# 3              26               [26, m²1, Quarto1, Banheiro1, Vaga]
# 4              31                      [31, m²1, Quarto1, Banheiro]
# 5              28               [28, m²1, Quarto1, Banheiro1, Vaga]
# 6              25                        [25, m²1, Banheiro1, Vaga]
# 7             600  [600, m²4, Quartos3, Suítes4, Banheiros2, Vagas]
# 8              80     [80, m²2, Quartos1, Suíte2, Banheiros1, Vaga]
# 9             280   [280, m²4, Quartos1, Suíte5, Banheiros8, Vagas]
# 10            144   [144, m²3, Quartos1, Suíte2, Banheiros2, Vagas]
# 11             63            [63, m²3, Quartos1, Suíte2, Banheiros]
